# %%
import os

# 주어진 디렉토리에 있는 항목들의 이름을 담고 있는 리스트를 반환합니다.
# 리스트는 임의의 순서대로 나열됩니다.
file_path = 'D:\RYU\Deep_learning\dataset\crop'
file_names = os.listdir(file_path)
file_names

# >>> ['photo-1577055209976-ddae617a8023.jpg', 'photo-1577255714682-69db9b067fda.jpg', ..., 'photo-1579122549707-440e9edc4a6d.jpg']
# Out:
# ['58177.jpg',
#  '58178.jpg',
#  '58179.jpg',
#  '58180.jpg',
#  '58181.jpg',
#  '58182.jpg',
#  '58183.jpg',
#  '58184.jpg',
#  '58185.jpg',
#  '58186.jpg',
#  '58187.jpg',
#  '58188.jpg',
#  '58189.jpg',
#  '58190.jpg',
#  '58191.jpg',
#  '58192.jpg',
#  '58193.jpg',
#  '58194.jpg',
#  '58195.jpg',
#  '58196.jpg',
#  '58197.jpg',
#  '58198.jpg',
#  '58199.jpg',
#  '58200.jpg',
#  '58201.jpg',
#  '58202.jpg',
#  '58203.jpg',
#  '58204.jpg',
#  '58205.jpg',
#  '58206.jpg',
#  '58207.jpg',
#  '58208.jpg',
#  '58209.jpg',
#  '58210.jpg',
#  '58211.jpg',
#  '58212.jpg',
#  '58213.jpg',
#  '58214.jpg',
#  '58215.jpg',
#  '58216.jpg',
#  '58217.jpg',
#  '58218.jpg',
#  '58219.jpg',
#  '58220.jpg',
#  '58221.jpg',
#  '58222.jpg',
#  '58223.jpg',
#  '58224.jpg',
#  '58225.jpg',
#  '58226.jpg',
#  '58227.jpg',
#  '58228.jpg',
#  '58229.jpg',
#  '58230.jpg',
#  '58231.jpg',
#  '58232.jpg',
#  '58233.jpg',
#  '58234.jpg',
#  '58235.jpg',
#  '58236.jpg',
#  '58237.jpg',
#  '58238.jpg',
# ...

# %%
i = 577
for name in file_names:
    src = os.path.join(file_path, name)
    dst = str(i) + '.jpg'
    dst = os.path.join(file_path, dst)
    os.rename(src, dst)
    i += 1

# %%
from PIL import Image

im = Image.open('D:\RYU\Deep_learning\dataset\crop\\1.jpg')

print(im.filename)
print(im.size)
print(im.width, im.height)
print(im.format)
# Out:
# D:\RYU\Deep_learning\dataset\crop\1.jpg
# (178, 218)
# 178 218
# JPEG

# %%
from PIL import Image

im = Image.open('D:\RYU\Deep_learning\dataset\Convert\Convert\\462.jpg')

im1 = im.crop((116, 116, 294, 334))
im1.save('D:\RYU\Deep_learning\dataset\crop\\1.jpg')

im2 = im.crop((294, 116, 472, 334))
im2.save('D:\RYU\Deep_learning\dataset\crop\\2.jpg')

im3 = im.crop((472, 116, 650, 334))
im3.save('D:\RYU\Deep_learning\dataset\crop\\3.jpg')

im4 = im.crop((650, 116, 828, 334))
im4.save('D:\RYU\Deep_learning\dataset\crop\\4.jpg')

im5 = im.crop((828, 116, 1006, 334))
im5.save('D:\RYU\Deep_learning\dataset\crop\\5.jpg')

im6 = im.crop((1006, 116, 1184, 334))
im6.save('D:\RYU\Deep_learning\dataset\crop\\6.jpg')

im7 = im.crop((1184, 116, 1362, 334))
im7.save('D:\RYU\Deep_learning\dataset\crop\\7.jpg')

im8 = im.crop((1362, 116, 1540, 334))
im8.save('D:\RYU\Deep_learning\dataset\crop\\8.jpg')

im9 = im.crop((1540, 116, 1718, 334))
im9.save('D:\RYU\Deep_learning\dataset\crop\\9.jpg')

im10 = im.crop((1718, 116, 1896, 334))
im10.save('D:\RYU\Deep_learning\dataset\crop\\10.jpg')

im11 = im.crop((1896, 116, 2074, 334))
im11.save('D:\RYU\Deep_learning\dataset\crop\\11.jpg')

im12 = im.crop((2074, 116, 2252, 334))
im12.save('D:\RYU\Deep_learning\dataset\crop\\12.jpg')

im13 = im.crop((116, 334, 294, 552))
im13.save('D:\RYU\Deep_learning\dataset\crop\\13.jpg')

im14 = im.crop((294, 334, 472, 552))
im14.save('D:\RYU\Deep_learning\dataset\crop\\14.jpg')

im15 = im.crop((472, 334, 650, 552))
im15.save('D:\RYU\Deep_learning\dataset\crop\\15.jpg')

im16 = im.crop((650, 334, 828, 552))
im16.save('D:\RYU\Deep_learning\dataset\crop\\16.jpg')

im17 = im.crop((828, 334, 1006, 552))
im17.save('D:\RYU\Deep_learning\dataset\crop\\17.jpg')

im18 = im.crop((1006, 334, 1184, 552))
im18.save('D:\RYU\Deep_learning\dataset\crop\\18.jpg')

im19 = im.crop((1184, 334, 1362, 552))
im19.save('D:\RYU\Deep_learning\dataset\crop\\19.jpg')

im20 = im.crop((1362, 334, 1540, 552))
im20.save('D:\RYU\Deep_learning\dataset\crop\\20.jpg')

im21 = im.crop((1540, 334, 1718, 552))
im21.save('D:\RYU\Deep_learning\dataset\crop\\21.jpg')

im22 = im.crop((1718, 334, 1896, 552))
im22.save('D:\RYU\Deep_learning\dataset\crop\\22.jpg')

im23 = im.crop((1896, 334, 2074, 552))
im23.save('D:\RYU\Deep_learning\dataset\crop\\23.jpg')

im24 = im.crop((2074, 334, 2252, 552))
im24.save('D:\RYU\Deep_learning\dataset\crop\\24.jpg')

im25 = im.crop((116, 552, 294, 770))
im25.save('D:\RYU\Deep_learning\dataset\crop\\25.jpg')

im26 = im.crop((294, 552, 472, 770))
im26.save('D:\RYU\Deep_learning\dataset\crop\\26.jpg')

im27 = im.crop((472, 552, 650, 770))
im27.save('D:\RYU\Deep_learning\dataset\crop\\27.jpg')

im28 = im.crop((650, 552, 828, 770))
im28.save('D:\RYU\Deep_learning\dataset\crop\\28.jpg')

im29 = im.crop((828, 552, 1006, 770))
im29.save('D:\RYU\Deep_learning\dataset\crop\\29.jpg')

im30 = im.crop((1006, 552, 1184, 770))
im30.save('D:\RYU\Deep_learning\dataset\crop\\30.jpg')

im31 = im.crop((1184, 552, 1362, 770))
im31.save('D:\RYU\Deep_learning\dataset\crop\\31.jpg')

im32 = im.crop((1362, 552, 1540, 770))
im32.save('D:\RYU\Deep_learning\dataset\crop\\32.jpg')

im33 = im.crop((1540, 552, 1718, 770))
im33.save('D:\RYU\Deep_learning\dataset\crop\\33.jpg')

im34 = im.crop((1718, 552, 1896, 770))
im34.save('D:\RYU\Deep_learning\dataset\crop\\34.jpg')

im35 = im.crop((1896, 552, 2074, 770))
im35.save('D:\RYU\Deep_learning\dataset\crop\\35.jpg')

im36 = im.crop((2074, 552, 2252, 770))
im36.save('D:\RYU\Deep_learning\dataset\crop\\36.jpg')

im37 = im.crop((116, 770, 294, 988))
im37.save('D:\RYU\Deep_learning\dataset\crop\\37.jpg')

im38 = im.crop((294, 770, 472, 988))
im38.save('D:\RYU\Deep_learning\dataset\crop\\38.jpg')

im39 = im.crop((472, 770, 650, 988))
im39.save('D:\RYU\Deep_learning\dataset\crop\\39.jpg')

im40 = im.crop((650, 770, 828, 988))
im40.save('D:\RYU\Deep_learning\dataset\crop\\40.jpg')

im41 = im.crop((828, 770, 1006, 988))
im41.save('D:\RYU\Deep_learning\dataset\crop\\41.jpg')

im42 = im.crop((1006, 770, 1184, 988))
im42.save('D:\RYU\Deep_learning\dataset\crop\\42.jpg')

im43 = im.crop((1184, 770, 1362, 988))
im43.save('D:\RYU\Deep_learning\dataset\crop\\43.jpg')

im44 = im.crop((1362, 770, 1540, 988))
im44.save('D:\RYU\Deep_learning\dataset\crop\\44.jpg')

im45 = im.crop((1540, 770, 1718, 988))
im45.save('D:\RYU\Deep_learning\dataset\crop\\45.jpg')

im46 = im.crop((1718, 770, 1896, 988))
im46.save('D:\RYU\Deep_learning\dataset\crop\\46.jpg')

im47 = im.crop((1896, 770, 2074, 988))
im47.save('D:\RYU\Deep_learning\dataset\crop\\47.jpg')

im48 = im.crop((2074, 770, 2252, 988))
im48.save('D:\RYU\Deep_learning\dataset\crop\\48.jpg')

im49 = im.crop((116, 988, 294, 1206))
im49.save('D:\RYU\Deep_learning\dataset\crop\\49.jpg')

im50 = im.crop((294, 988, 472, 1206))
im50.save('D:\RYU\Deep_learning\dataset\crop\\50.jpg')

im51 = im.crop((472, 988, 650, 1206))
im51.save('D:\RYU\Deep_learning\dataset\crop\\51.jpg')

im52 = im.crop((650, 988, 828, 1206))
im52.save('D:\RYU\Deep_learning\dataset\crop\\52.jpg')

im53 = im.crop((828, 988, 1006, 1206))
im53.save('D:\RYU\Deep_learning\dataset\crop\\53.jpg')

im54 = im.crop((1006, 988, 1184, 1206))
im54.save('D:\RYU\Deep_learning\dataset\crop\\54.jpg')

im55 = im.crop((1184, 988, 1362, 1206))
im55.save('D:\RYU\Deep_learning\dataset\crop\\55.jpg')

im56 = im.crop((1362, 988, 1540, 1206))
im56.save('D:\RYU\Deep_learning\dataset\crop\\56.jpg')

im57 = im.crop((1540, 988, 1718, 1206))
im57.save('D:\RYU\Deep_learning\dataset\crop\\57.jpg')

im58 = im.crop((1718, 988, 1896, 1206))
im58.save('D:\RYU\Deep_learning\dataset\crop\\58.jpg')

im59 = im.crop((1896, 988, 2074, 1206))
im59.save('D:\RYU\Deep_learning\dataset\crop\\59.jpg')

im60 = im.crop((2074, 988, 2252, 1206))
im60.save('D:\RYU\Deep_learning\dataset\crop\\60.jpg')

im61 = im.crop((116, 1206, 294, 1424))
im61.save('D:\RYU\Deep_learning\dataset\crop\\61.jpg')

im62 = im.crop((294, 1206, 472, 1424))
im62.save('D:\RYU\Deep_learning\dataset\crop\\62.jpg')

im63 = im.crop((472, 1206, 650, 1424))
im63.save('D:\RYU\Deep_learning\dataset\crop\\63.jpg')

im64 = im.crop((650, 1206, 828, 1424))
im64.save('D:\RYU\Deep_learning\dataset\crop\\64.jpg')

im65 = im.crop((828, 1206, 1006, 1424))
im65.save('D:\RYU\Deep_learning\dataset\crop\\65.jpg')

im66 = im.crop((1006, 1206, 1184, 1424))
im66.save('D:\RYU\Deep_learning\dataset\crop\\66.jpg')

im67 = im.crop((1184, 1206, 1362, 1424))
im67.save('D:\RYU\Deep_learning\dataset\crop\\67.jpg')

im68 = im.crop((1362, 1206, 1540, 1424))
im68.save('D:\RYU\Deep_learning\dataset\crop\\68.jpg')

im69 = im.crop((1540, 1206, 1718, 1424))
im69.save('D:\RYU\Deep_learning\dataset\crop\\69.jpg')

im70 = im.crop((1718, 1206, 1896, 1424))
im70.save('D:\RYU\Deep_learning\dataset\crop\\70.jpg')

im71 = im.crop((1896, 1206, 2074, 1424))
im71.save('D:\RYU\Deep_learning\dataset\crop\\71.jpg')

im72 = im.crop((2074, 1206, 2252, 1424))
im72.save('D:\RYU\Deep_learning\dataset\crop\\72.jpg')

im73 = im.crop((116, 1424, 294, 1642))
im73.save('D:\RYU\Deep_learning\dataset\crop\\73.jpg')

im74 = im.crop((294, 1424, 472, 1642))
im74.save('D:\RYU\Deep_learning\dataset\crop\\74.jpg')

im75 = im.crop((472, 1424, 650, 1642))
im75.save('D:\RYU\Deep_learning\dataset\crop\\75.jpg')

im76 = im.crop((650, 1424, 828, 1642))
im76.save('D:\RYU\Deep_learning\dataset\crop\\76.jpg')

im77 = im.crop((828, 1424, 1006, 1642))
im77.save('D:\RYU\Deep_learning\dataset\crop\\77.jpg')

im78 = im.crop((1006, 1424, 1184, 1642))
im78.save('D:\RYU\Deep_learning\dataset\crop\\78.jpg')

im79 = im.crop((1184, 1424, 1362, 1642))
im79.save('D:\RYU\Deep_learning\dataset\crop\\79.jpg')

im80 = im.crop((1362, 1424, 1540, 1642))
im80.save('D:\RYU\Deep_learning\dataset\crop\\80.jpg')

im81 = im.crop((1540, 1424, 1718, 1642))
im81.save('D:\RYU\Deep_learning\dataset\crop\\81.jpg')

im82 = im.crop((1718, 1424, 1896, 1642))
im82.save('D:\RYU\Deep_learning\dataset\crop\\82.jpg')

im83 = im.crop((1896, 1424, 2074, 1642))
im83.save('D:\RYU\Deep_learning\dataset\crop\\83.jpg')

im84 = im.crop((2074, 1424, 2252, 1642))
im84.save('D:\RYU\Deep_learning\dataset\crop\\84.jpg')

im85 = im.crop((116, 1642, 294, 1860))
im85.save('D:\RYU\Deep_learning\dataset\crop\\85.jpg')

im86 = im.crop((294, 1642, 472, 1860))
im86.save('D:\RYU\Deep_learning\dataset\crop\\86.jpg')

im87 = im.crop((472, 1642, 650, 1860))
im87.save('D:\RYU\Deep_learning\dataset\crop\\87.jpg')

im88 = im.crop((650, 1642, 828, 1860))
im88.save('D:\RYU\Deep_learning\dataset\crop\\88.jpg')

im89 = im.crop((828, 1642, 1006, 1860))
im89.save('D:\RYU\Deep_learning\dataset\crop\\89.jpg')

im90 = im.crop((1006, 1642, 1184, 1860))
im90.save('D:\RYU\Deep_learning\dataset\crop\\90.jpg')

im91 = im.crop((1184, 1642, 1362, 1860))
im91.save('D:\RYU\Deep_learning\dataset\crop\\91.jpg')

im92 = im.crop((1362, 1642, 1540, 1860))
im92.save('D:\RYU\Deep_learning\dataset\crop\\92.jpg')

im93 = im.crop((1540, 1642, 1718, 1860))
im93.save('D:\RYU\Deep_learning\dataset\crop\\93.jpg')

im94 = im.crop((1718, 1642, 1896, 1860))
im94.save('D:\RYU\Deep_learning\dataset\crop\\94.jpg')

im95 = im.crop((1896, 1642, 2074, 1860))
im95.save('D:\RYU\Deep_learning\dataset\crop\\95.jpg')

im96 = im.crop((2074, 1642, 2252, 1860))
im96.save('D:\RYU\Deep_learning\dataset\crop\\96.jpg')

im97 = im.crop((116, 1860, 294, 2078))
im97.save('D:\RYU\Deep_learning\dataset\crop\\97.jpg')

im98 = im.crop((294, 1860, 472, 2078))
im98.save('D:\RYU\Deep_learning\dataset\crop\\98.jpg')

im99 = im.crop((472, 1860, 650, 2078))
im99.save('D:\RYU\Deep_learning\dataset\crop\\99.jpg')

im100 = im.crop((650, 1860, 828, 2078))
im100.save('D:\RYU\Deep_learning\dataset\crop\\100.jpg')

im101 = im.crop((828, 1860, 1006, 2078))
im101.save('D:\RYU\Deep_learning\dataset\crop\\101.jpg')

im102 = im.crop((1006, 1860, 1184, 2078))
im102.save('D:\RYU\Deep_learning\dataset\crop\\102.jpg')

im103 = im.crop((1184, 1860, 1362, 2078))
im103.save('D:\RYU\Deep_learning\dataset\crop\\103.jpg')

im104 = im.crop((1362, 1860, 1540, 2078))
im104.save('D:\RYU\Deep_learning\dataset\crop\\104.jpg')

im105 = im.crop((1540, 1860, 1718, 2078))
im105.save('D:\RYU\Deep_learning\dataset\crop\\105.jpg')

im106 = im.crop((1718, 1860, 1896, 2078))
im106.save('D:\RYU\Deep_learning\dataset\crop\\106.jpg')

im107 = im.crop((1896, 1860, 2074, 2078))
im107.save('D:\RYU\Deep_learning\dataset\crop\\107.jpg')

im108 = im.crop((2074, 1860, 2252, 2078))
im108.save('D:\RYU\Deep_learning\dataset\crop\\108.jpg')

im109 = im.crop((116, 2078, 294, 2296))
im109.save('D:\RYU\Deep_learning\dataset\crop\\109.jpg')

im110 = im.crop((294, 2078, 472, 2296))
im110.save('D:\RYU\Deep_learning\dataset\crop\\110.jpg')

im111 = im.crop((472, 2078, 650, 2296))
im111.save('D:\RYU\Deep_learning\dataset\crop\\111.jpg')

im112 = im.crop((650, 2078, 828, 2296))
im112.save('D:\RYU\Deep_learning\dataset\crop\\112.jpg')

im113 = im.crop((828, 2078, 1006, 2296))
im113.save('D:\RYU\Deep_learning\dataset\crop\\113.jpg')

im114 = im.crop((1006, 2078, 1184, 2296))
im114.save('D:\RYU\Deep_learning\dataset\crop\\114.jpg')

im115 = im.crop((1184, 2078, 1362, 2296))
im115.save('D:\RYU\Deep_learning\dataset\crop\\115.jpg')

im116 = im.crop((1362, 2078, 1540, 2296))
im116.save('D:\RYU\Deep_learning\dataset\crop\\116.jpg')

im117 = im.crop((1540, 2078, 1718, 2296))
im117.save('D:\RYU\Deep_learning\dataset\crop\\117.jpg')

im118 = im.crop((1718, 2078, 1896, 2296))
im118.save('D:\RYU\Deep_learning\dataset\crop\\118.jpg')

im119 = im.crop((1896, 2078, 2074, 2296))
im119.save('D:\RYU\Deep_learning\dataset\crop\\119.jpg')

im120 = im.crop((2074, 2078, 2252, 2296))
im120.save('D:\RYU\Deep_learning\dataset\crop\\120.jpg')

im121 = im.crop((116, 2296, 294, 2514))
im121.save('D:\RYU\Deep_learning\dataset\crop\\121.jpg')

im122 = im.crop((294, 2296, 472, 2514))
im122.save('D:\RYU\Deep_learning\dataset\crop\\122.jpg')

im123 = im.crop((472, 2296, 650, 2514))
im123.save('D:\RYU\Deep_learning\dataset\crop\\123.jpg')

im124 = im.crop((650, 2296, 828, 2514))
im124.save('D:\RYU\Deep_learning\dataset\crop\\124.jpg')

im125 = im.crop((828, 2296, 1006, 2514))
im125.save('D:\RYU\Deep_learning\dataset\crop\\125.jpg')

im126 = im.crop((1006, 2296, 1184, 2514))
im126.save('D:\RYU\Deep_learning\dataset\crop\\126.jpg')

im127 = im.crop((1184, 2296, 1362, 2514))
im127.save('D:\RYU\Deep_learning\dataset\crop\\127.jpg')

im128 = im.crop((1362, 2296, 1540, 2514))
im128.save('D:\RYU\Deep_learning\dataset\crop\\128.jpg')

im129 = im.crop((1540, 2296, 1718, 2514))
im129.save('D:\RYU\Deep_learning\dataset\crop\\129.jpg')

im130 = im.crop((1718, 2296, 1896, 2514))
im130.save('D:\RYU\Deep_learning\dataset\crop\\130.jpg')

im131 = im.crop((1896, 2296, 2074, 2514))
im131.save('D:\RYU\Deep_learning\dataset\crop\\131.jpg')

im132 = im.crop((2074, 2296, 2252, 2514))
im132.save('D:\RYU\Deep_learning\dataset\crop\\132.jpg')

im133 = im.crop((116, 2514, 294, 2732))
im133.save('D:\RYU\Deep_learning\dataset\crop\\133.jpg')

im134 = im.crop((294, 2514, 472, 2732))
im134.save('D:\RYU\Deep_learning\dataset\crop\\134.jpg')

im135 = im.crop((472, 2514, 650, 2732))
im135.save('D:\RYU\Deep_learning\dataset\crop\\135.jpg')

im136 = im.crop((650, 2514, 828, 2732))
im136.save('D:\RYU\Deep_learning\dataset\crop\\136.jpg')

im137 = im.crop((828, 2514, 1006, 2732))
im137.save('D:\RYU\Deep_learning\dataset\crop\\137.jpg')

im138 = im.crop((1006, 2514, 1184, 2732))
im138.save('D:\RYU\Deep_learning\dataset\crop\\138.jpg')

im139 = im.crop((1184, 2514, 1362, 2732))
im139.save('D:\RYU\Deep_learning\dataset\crop\\139.jpg')

im140 = im.crop((1362, 2514, 1540, 2732))
im140.save('D:\RYU\Deep_learning\dataset\crop\\140.jpg')

im141 = im.crop((1540, 2514, 1718, 2732))
im141.save('D:\RYU\Deep_learning\dataset\crop\\141.jpg')

im142 = im.crop((1718, 2514, 1896, 2732))
im142.save('D:\RYU\Deep_learning\dataset\crop\\142.jpg')

im143 = im.crop((1896, 2514, 2074, 2732))
im143.save('D:\RYU\Deep_learning\dataset\crop\\143.jpg')

im144 = im.crop((2074, 2514, 2252, 2732))
im144.save('D:\RYU\Deep_learning\dataset\crop\\144.jpg')

# %%
import os

file_path = 'D:\RYU\Deep_learning\dataset\crop'
file_names = os.listdir(file_path)

i = 65578
for name in file_names:
    src = os.path.join(file_path, name)
    dst = str(i) + '.jpg'
    dst = os.path.join(file_path, dst)
    os.rename(src, dst)
    i += 1
