# %% [markdown]
# <a href="https://colab.research.google.com/github/rjm135/Deeplearning/blob/master/SRCNN(test).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir SRCNN

# %%
# !mv SRCNN-Tensorflow-master.zip ./drive/MyDrive/SRCNN/

# %%
import os
os.chdir('/content/drive/MyDrive')

# %%
# !cd SRCNN && unzip SRCNN-Tensorflow-master.zip
# Out:
# Archive:  SRCNN-Tensorflow-master.zip
# 78be1a24697935fc39a3a8cf59a6632264afade7
#    creating: SRCNN-Tensorflow-master/
#   inflating: SRCNN-Tensorflow-master/.gitignore
#   inflating: SRCNN-Tensorflow-master/LICENSE
#   inflating: SRCNN-Tensorflow-master/README.md
#    creating: SRCNN-Tensorflow-master/Test/
#    creating: SRCNN-Tensorflow-master/Test/Set14/
#   inflating: SRCNN-Tensorflow-master/Test/Set14/baboon.bmp
#   inflating: SRCNN-Tensorflow-master/Test/Set14/barbara.bmp
#   inflating: SRCNN-Tensorflow-master/Test/Set14/bridge.bmp
#   inflating: SRCNN-Tensorflow-master/Test/Set14/coastguard.bmp
#   inflating: SRCNN-Tensorflow-master/Test/Set14/comic.bmp
#   inflating: SRCNN-Tensorflow-master/Test/Set14/face.bmp
#   inflating: SRCNN-Tensorflow-master/Test/Set14/flowers.bmp
#   inflating: SRCNN-Tensorflow-master/Test/Set14/foreman.bmp
#   inflating: SRCNN-Tensorflow-master/Test/Set14/lenna.bmp
#   inflating: SRCNN-Tensorflow-master/Test/Set14/man.bmp
# ...

# %%
# !ls -al SRCNN
# Out:
# total 20436
# drwx------  6 root root     4096 Dec 20  2017 SRCNN-Tensorflow-master
# -rw-------+ 1 root root 20922312 Dec  1 12:41 SRCNN-Tensorflow-master.zip

# %%
# !ls
# Out:
#  10ea  'AI 집체교육.gdoc'  'Colab Notebooks'   SRCNN   tmp

# %%
import os
os.chdir('/content/drive/MyDrive/SRCNN/SRCNN-Tensorflow-master')

# %%
# !ls
# Out:
# checkpoint  main.py   __pycache__  result  Test   utils.py
# LICENSE     model.py  README.md    sample  Train

# %%
# !pip install scipy==1.1.0
# Out:
# ...
#      |████████████████████████████████| 31.2MB 101kB/s
# ...
# ERROR: umap-learn 0.4.6 has requirement scipy>=1.3.1, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement scipy==1.4.1, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ...

# %%
# %run -i main.py
# Out:
# {'?': <absl.app.HelpFlag object at 0x7fdea6fd7fd0>,
#  'alsologtostderr': <absl.flags._flag.BooleanFlag object at 0x7fded2f70c88>,
#  'batch_size': <absl.flags._flag.Flag object at 0x7fdee1dc9cf8>,
#  'c_dim': <absl.flags._flag.Flag object at 0x7fded4932f60>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fded31f4048>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fdee1dc95f8>,
#  'help': <absl.app.HelpFlag object at 0x7fdea6fd7fd0>,
#  'helpfull': <absl.app.HelpfullFlag object at 0x7fdea6f94160>,
#  'helpshort': <absl.app.HelpshortFlag object at 0x7fdea6f940f0>,
#  'helpxml': <absl.app.HelpXMLFlag object at 0x7fdea6f941d0>,
#  'image_size': <absl.flags._flag.Flag object at 0x7fdee1dc9e10>,
#  'is_train': <absl.flags._flag.BooleanFlag object at 0x7fded32019b0>,
#  'label_size': <absl.flags._flag.Flag object at 0x7fded3453ac8>,
#  'learning_rate': <absl.flags._flag.Flag object at 0x7fdee0f2f1d0>,
#  'log_dir': <absl.flags._flag.Flag object at 0x7fded2f144a8>,
# ...

# %%
# %run -i main.py --is_train False --stride 21
# Out:
# {'?': <absl.app.HelpFlag object at 0x7fb2555abf98>,
#  'alsologtostderr': <absl.flags._flag.BooleanFlag object at 0x7fb281545c88>,
#  'batch_size': <absl.flags._flag.Flag object at 0x7fb28fd71da0>,
#  'c_dim': <absl.flags._flag.Flag object at 0x7fb28b6ee898>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fb281a59390>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fb28fd71588>,
#  'help': <absl.app.HelpFlag object at 0x7fb2555abf98>,
#  'helpfull': <absl.app.HelpfullFlag object at 0x7fb255568128>,
#  'helpshort': <absl.app.HelpshortFlag object at 0x7fb2555680b8>,
#  'helpxml': <absl.app.HelpXMLFlag object at 0x7fb255568198>,
#  'image_size': <absl.flags._flag.Flag object at 0x7fb28fd71e10>,
#  'is_train': <absl.flags._flag.BooleanFlag object at 0x7fb2817d2860>,
#  'label_size': <absl.flags._flag.Flag object at 0x7fb28fe09e80>,
#  'learning_rate': <absl.flags._flag.Flag object at 0x7fb281a48cf8>,
#  'log_dir': <absl.flags._flag.Flag object at 0x7fb2814dd4a8>,
# ...
